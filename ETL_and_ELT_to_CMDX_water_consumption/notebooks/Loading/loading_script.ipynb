# %% [markdown]
# # Extraction Examples

# %% [markdown]
# Para empezar, realizaremos las importaciones necesarias para extraer y cargar los datos:

# %%
import pandas as pd
import requests
import json
import csv
import psycopg2
import boto3
import configparser

# %% [markdown]
# En este notebook encontraremos 3 ejemplos de extracción;
# * Extraer datos desde la computadora local
# * Extraer un csv desde una liga
# * Extraer datos desde una API
# * Extraer datos desde una base de datos en AWS

# %% [markdown]
# ## Extracción de datos desde la computadora local

# %% [markdown]
# En la carpeta de `data` encontrarás un csv, el cual será extraído localmente utilizando la librería de pandas.

# %%
convocatorias = pd.read_csv('../../data/convocatorias_20092021.csv')
convocatorias.head()
# Out:
#                                           post_title      post_date  \
# 0  2ª ADQUISICIÓN DE EQUIPAMIENTO DE MOBILIARIO, ...  20/09/21 0:51
# 1             ADQUISICIÓN DE MOBILIARIO PARA OFICINA  20/09/21 0:44
# 2  EQUIPAMIENTO DE COCINAS PROTOTIPO PARA ALIMENT...  20/09/21 0:38
# 3         ADQUISICIÓN DE ENZIMAS Y PUNTAS CON FILTRO  20/09/21 0:27
# 4  TRABAJOS DE MANTENIMIENTO, CONSERVACIÓN Y REHA...  20/09/21 0:25
#
#            no_procedimiento  \
# 0        UNISA/LPI/003/2021
# 1       LPN/SACMEX/019/2021
# 2       LPN-SIBISO-005-2021
# 3  LPI/FGJCDMX/DACS022/2021
# 4          3000-1116-085-21
#
#                                   unidad_responsable id_convocante  \
# 0             DIRECCIÓN DE ADMINISTRACIÓN Y FINANZAS           NaN
# 1  DIRECCIÓN DE RECURSOS MATERIALES, ABASTECIMIEN...        06CD03
# 2     DIRECCIÓN GENERAL DE ADMINISTRACIÓN Y FINANZAS        08C001
# 3  DIRECCIÓN GENERAL DE RECURSOS MATERIALES Y SER...           NaN
# ...

# %% [markdown]
# ## Extracción mediante una liga a un csv expuesto

# %% [markdown]
# En esta ocasión usaremos la liga en donde se encuentra el csv para extraerlo.
# Estos datos se encuentran en la página de datos [abiertos de la CDMX](https://datos.cdmx.gob.mx/dataset/convocatorias-de-compras-publicas).

# %%
convocatorias = pd.read_csv('https://datos.cdmx.gob.mx/dataset/a16471a6-2a7d-4c7d-996e-d804f8ad3772/resource/e20d341a-5558-4a84-be33-31aee566ccbd/download/convocatorias_20092021.csv')
convocatorias.head()
# Out:
#                                           post_title      post_date  \
# 0  2ª ADQUISICIÓN DE EQUIPAMIENTO DE MOBILIARIO, ...  20/09/21 0:51
# 1             ADQUISICIÓN DE MOBILIARIO PARA OFICINA  20/09/21 0:44
# 2  EQUIPAMIENTO DE COCINAS PROTOTIPO PARA ALIMENT...  20/09/21 0:38
# 3         ADQUISICIÓN DE ENZIMAS Y PUNTAS CON FILTRO  20/09/21 0:27
# 4  TRABAJOS DE MANTENIMIENTO, CONSERVACIÓN Y REHA...  20/09/21 0:25
#
#            no_procedimiento  \
# 0        UNISA/LPI/003/2021
# 1       LPN/SACMEX/019/2021
# 2       LPN-SIBISO-005-2021
# 3  LPI/FGJCDMX/DACS022/2021
# 4          3000-1116-085-21
#
#                                   unidad_responsable id_convocante  \
# 0             DIRECCIÓN DE ADMINISTRACIÓN Y FINANZAS           NaN
# 1  DIRECCIÓN DE RECURSOS MATERIALES, ABASTECIMIEN...        06CD03
# 2     DIRECCIÓN GENERAL DE ADMINISTRACIÓN Y FINANZAS        08C001
# 3  DIRECCIÓN GENERAL DE RECURSOS MATERIALES Y SER...           NaN
# ...

# %% [markdown]
# ## Extracción de datos mediante una API

# %% [markdown]
# Como vimos anteriormente, una API es un protocolo de comunicación entre sistemas que "deja expuestos" ciertos datos, para que otro sistema los pueda leer desde ahí.
#
# Para leer datos desde una API, utilizaremos la base de datos de consultas de información al INAI.
#
# Para ello, utilizaremos la paquetería de requests.
#
# Es importante conocer los tipos de respuesta que nos puede dar una API. Los principales son los siguientes:
# * 200: OK
# * 400: Bad Request
# * 401: Unauthorised
# * 402: Payment Required
# * 403: Forbidden
# * 404: Not Found
#
# Ahora, vamos a hacer una solicitud de información a la API de [datos abiertos de méxico](https://datos.gob.mx/blog/catalogo-apidatosgobmx)
#
# Los datos de la api puedes verlos "expuestos" en la siguiente [liga](https://api.datos.gob.mx/v1/inai.solicitudes)

# %% [markdown]
# ¿Qué sucede si hago una request a una api que no existe?

# %%
date = '01/08/2020'
data_raw = requests.get(f"https://datos.cdmx.gob.mx/api/records/1.0/search/?dataset=afluencia-diaria-del-metro-cdmx&rows=10000&sort=-fecha&refine.fecha={date}")
data_raw
# Out:
# <Response [404]>

# %% [markdown]
# Primero hacemos el "request" de información a la API. Esto nos regresará como resultado un código de respuesta:

# %%
data_raw = requests.get('https://api.datos.gob.mx/v1/inai.solicitudes')
data_raw
# Out:
# <Response [200]>

# %% [markdown]
# Podemos ver el contenido de la extracción de la siguiente forma, pero no es legible para el humano.

# %%
# data_raw.content

# %% [markdown]
# Para poder entenderlo como humanos, tenemos que realizar lo siguiente:

# %%
data = data_raw.text
json_data = json.loads(data)
pandas_data = pd.json_normalize(json_data['results'])
pandas_data.head(5)
# Out:
#                         _id           FOLIO    FECHASOLICITUD  \
# 0  56eb2f18d288290100392fb6  '0673800000103  12/06/2003 07:42
# 1  56eb2f18d288290100392fb7  '0673800000203  12/06/2003 07:42
# 2  56eb2f18d288290100392fb8  '0608400000103  12/06/2003 07:47
# 3  56eb2f18d288290100392fb9  '0000700000103  12/06/2003 08:10
# 4  56eb2f18d288290100392fba  '0000700000203  12/06/2003 08:11
#
#                                          DEPENDENCIA    ESTATUS MEDIOENTRADA  \
# 0  INSTITUTO FEDERAL DE ACCESO A LA INFORMACIÓN Y...  Terminada  Electrónica
# 1  INSTITUTO FEDERAL DE ACCESO A LA INFORMACIÓN Y...  Terminada  Electrónica
# 2                                   AGROASEMEX  S.A.  Terminada  Electrónica
# 3                  SECRETARÍA DE LA DEFENSA NACIONAL  Terminada  Electrónica
# 4                  SECRETARÍA DE LA DEFENSA NACIONAL  Terminada  Electrónica
#
#          TIPOSOLICITUD                               DESCRIPCIONSOLICITUD  \
# ...

# %% [markdown]
# ## Extracción de datos desde una base de datos

# %% [markdown]
# Para extraer datos de una base de datos directamente, es necesario conectarse a ella primero, para lo cual ejecutamos el siguiente código:

# %%
parser = configparser.ConfigParser()
parser.read("../../pipeline.conf")
dbname = parser.get("postgres_config","database")
user = parser.get("postgres_config","username")
password = parser.get("postgres_config","password")
host = parser.get("postgres_config","host")
port = parser.get("postgres_config","port")

conn = psycopg2.connect(" dbname="+ dbname
                        + " user=" + user
                        + " password=" + password
                        + " host=" + host,
                        port = port)

# %% [markdown]
# Creamos un texto con el formato de query normal de SQL:

# %%
query = "SELECT * FROM Ordenes"

# %%
cursor = conn.cursor()
cursor.execute(query)
results = cursor.fetchall()

# %% [markdown]
# Verificamos los nombres de las columnas

# %%
column_names = [desc[0] for desc in cursor.description]
for i in column_names:
    print(i)
# Out:
# id_cliente
# cantidad_de_chapatas
# estatus
# precio_chapatas
# lastupdated

# %%
# Extract the column names
col_names = []
for elt in cursor.description:
    col_names.append(elt[0])

# %%
# Create the dataframe, passing in the list of col_names extracted from the description
df_rds_aws = pd.DataFrame(results, columns=col_names)

# %%
df_rds_aws
# Out:
#    id_cliente  cantidad_de_chapatas      estatus  precio_chapatas  \
# 0           1                     2  Backordered              190
# 1           2                     2      Shipped              190
# 2           1                     1    Delivered               95
# 3           3                     2  Backordered              190
# 4           4                     2      Shipped              190
# 5           5                     2    Delivered              190
# 6           6                     3  Backordered              285
# 7           7                     2      Shipped              190
# 8           8                     4  Backordered              380
# 9           4                     2      Shipped              190
#
#           lastupdated
# 0 2021-10-09 12:00:00
# 1 2021-10-09 13:00:00
# 2 2021-10-09 12:30:00
# 3 2021-10-09 15:00:00
# 4 2021-10-09 10:00:00
# 5 2021-10-09 16:20:00
# 6 2021-10-09 09:00:00
# 7 2021-10-09 18:50:00
# 8 2021-10-09 14:30:00
# ...

# %%
cursor.close()
conn.close()

# %% [markdown]
# # Loading Examples

# %% [markdown]
# Ahora, vamos a "cargar" los datos.

# %% [markdown]
# ## Carga de forma local:

# %% [markdown]
# para escribir los datos localmente en algún lugar, podemos hacerlo directamente con pandas, utilizando la función to_csv(), por lo que nuevamente ocuparemos la librería de pandas.

# %%
import pandas as pd
import requests
import json
import csv
import psycopg2
import boto3
import configparser
from sqlalchemy import create_engine

# %%
convocatorias.head(3)
# Out:
#                                           post_title      post_date  \
# 0  2ª ADQUISICIÓN DE EQUIPAMIENTO DE MOBILIARIO, ...  20/09/21 0:51
# 1             ADQUISICIÓN DE MOBILIARIO PARA OFICINA  20/09/21 0:44
# 2  EQUIPAMIENTO DE COCINAS PROTOTIPO PARA ALIMENT...  20/09/21 0:38
#
#        no_procedimiento                                 unidad_responsable  \
# 0    UNISA/LPI/003/2021             DIRECCIÓN DE ADMINISTRACIÓN Y FINANZAS
# 1   LPN/SACMEX/019/2021  DIRECCIÓN DE RECURSOS MATERIALES, ABASTECIMIEN...
# 2   LPN-SIBISO-005-2021     DIRECCIÓN GENERAL DE ADMINISTRACIÓN Y FINANZAS
#
#   id_convocante               entidad_convocante  ID      tipo_contratacion  \
# 0           NaN          UNIVERSIDAD DE LA SALUD   2  ADQUISICIÓN DE BIENES
# 1        06CD03                 SISTEMA DE AGUAS   3  ADQUISICIÓN DE BIENES
# 2        08C001  SECRETARÍA DE DESARROLLO SOCIAL   4  ADQUISICIÓN DE BIENES
#
#   metodo_contratacion  caracter_convocatoria  ... fecha_estimada_fin  \
# ...

# %% [markdown]
# Para escribir el archivo de forma local, lo único que tenemos que hacer es ponerle a la función la ruta y el nombre con el cual queremos guardar la información.

# %%
convocatorias.to_csv('../../data/convocatorias.csv')

# %% [markdown]
# Ahora, si leemos nuevamente el archivo que acabamos de escribir, veremos que tenemos una columna adicional llamada "Unnamed".
#
# Por esto, yo te recomiendo que, si el índice del DataFrame de pandas no tiene ningún significado para tí, lo excluyas en el guardado, para que no tengas este tipo de errores en la carga de tus datos.

# %%
convocatorias_1 = pd.read_csv('../../data/convocatorias.csv')
convocatorias_1.head(2)
# Out:
#    Unnamed: 0                                         post_title  \
# 0           0  2ª ADQUISICIÓN DE EQUIPAMIENTO DE MOBILIARIO, ...
# 1           1             ADQUISICIÓN DE MOBILIARIO PARA OFICINA
#
#        post_date      no_procedimiento  \
# 0  20/09/21 0:51    UNISA/LPI/003/2021
# 1  20/09/21 0:44   LPN/SACMEX/019/2021
#
#                                   unidad_responsable id_convocante  \
# 0             DIRECCIÓN DE ADMINISTRACIÓN Y FINANZAS           NaN
# 1  DIRECCIÓN DE RECURSOS MATERIALES, ABASTECIMIEN...        06CD03
#
#         entidad_convocante  ID      tipo_contratacion metodo_contratacion  \
# 0  UNIVERSIDAD DE LA SALUD   2  ADQUISICIÓN DE BIENES  LICITACIÓN PÚBLICA
# 1         SISTEMA DE AGUAS   3  ADQUISICIÓN DE BIENES  LICITACIÓN PÚBLICA
#
#    ... fecha_estimada_fin                                     concurso_lugar  \
# 0  ...         0000-00-00             OFICINAS DE LA UNIVERSIDAD DE LA SALUD
# ...

# %% [markdown]
# Para esto, simplemente tenemos que usar una variable de la función de to_csv para que se elimine este error:

# %%
convocatorias.to_csv('../../data/convocatorias.csv',index=False)
convocatorias_1 = pd.read_csv('../../data/convocatorias.csv')
convocatorias_1.head(2)
# Out:
#                                           post_title      post_date  \
# 0  2ª ADQUISICIÓN DE EQUIPAMIENTO DE MOBILIARIO, ...  20/09/21 0:51
# 1             ADQUISICIÓN DE MOBILIARIO PARA OFICINA  20/09/21 0:44
#
#        no_procedimiento                                 unidad_responsable  \
# 0    UNISA/LPI/003/2021             DIRECCIÓN DE ADMINISTRACIÓN Y FINANZAS
# 1   LPN/SACMEX/019/2021  DIRECCIÓN DE RECURSOS MATERIALES, ABASTECIMIEN...
#
#   id_convocante       entidad_convocante  ID      tipo_contratacion  \
# 0           NaN  UNIVERSIDAD DE LA SALUD   2  ADQUISICIÓN DE BIENES
# 1        06CD03         SISTEMA DE AGUAS   3  ADQUISICIÓN DE BIENES
#
#   metodo_contratacion  caracter_convocatoria  ... fecha_estimada_fin  \
# 0  LICITACIÓN PÚBLICA  INTERNACIONAL ABIERTA  ...         0000-00-00
# 1  LICITACIÓN PÚBLICA               NACIONAL  ...         0000-00-00
#
#                                       concurso_lugar  \
# 0             OFICINAS DE LA UNIVERSIDAD DE LA SALUD
# ...

# %% [markdown]
# ## Carga de datos en una instancia S3 en AWS:

# %% [markdown]
# Como te mencioné anteriormente, una instancia S3 es para almacenar objetos. De modo que podríamos almacenar un archivo csv en ella. Para esto, primero necesitamos conectarnos a la instancia.

# %%
# Load the aws_boto_credentials values
parser = configparser.ConfigParser()
parser.read("../../pipeline.conf")
access_key = parser.get("aws_boto_credentials","access_key")
secret_key = parser.get("aws_boto_credentials","secret_key")
bucket_name = parser.get("aws_boto_credentials","bucket_name")

s3 = boto3.client('s3',aws_access_key_id = access_key, aws_secret_access_key = secret_key)
convocatorias_path = "../../data/convocatorias.csv"
s3_file_name  = "convocatorias.csv"
# with open(s3_file_name,'w') as fp:
#     csv_w = csv.writer(fp)
#     csv_w.writerows(convocatorias)
# fp.close()

# %% [markdown]
# Ahora, cargamos los datos

# %%
s3.upload_file(
    convocatorias_path,
    bucket_name,
    s3_file_name)

# %% [markdown]
# Listo, ahora el archivo se encuentra cargado en nuestra bucket de s3.

# %% [markdown]
# ## Carga de datos en una instancia RDS de AWS

# %% [markdown]
# Ahora, escribiremos sobre una nueva tabla de nuestra RDS para mostrar la carga a una base de datos

# %%
parser = configparser.ConfigParser()
parser.read("../../pipeline.conf")
dbname = parser.get("postgres_config","database")
user = parser.get("postgres_config","username")
password = parser.get("postgres_config","password")
host = parser.get("postgres_config","host")
port = parser.get("postgres_config","port")


conn_string = f"postgresql://{user}:{password}@{host}/{dbname}"
db = create_engine(conn_string)
conn = db.connect()


# conn = psycopg2.connect(" dbname="+ dbname
#                         + " user=" + user
#                         + " password=" + password
#                         + " host=" + host,
#                         port = port)

# %%
# convocatorias.columns

# %%
convocatorias.to_sql("convocatorias", con = conn, if_exists="replace",index=False)
conn = psycopg2.connect(conn_string)
conn.autocommit = True
cursor = conn.cursor()

# %%
query = "SELECT * FROM convocatorias"

# %%
cursor = conn.cursor()
cursor.execute(query)
results = cursor.fetchall()

# %%
column_names = [desc[0] for desc in cursor.description]
for i in column_names:
    print(i)
# Out:
# post_title
# post_date
# no_procedimiento
# unidad_responsable
# id_convocante
# entidad_convocante
# ID
# tipo_contratacion
# metodo_contratacion
# caracter_convocatoria
# clasificador_bien_servicio
# servidor_nombre
# servidor_cargo
# lugar_venta
# domicilio_venta
# primer_entrega
# primer_entrega_fin
# segunda_entrega
# segunda_entrega_fin
# tercera_entrega
# tercera_entrega_fin
# cuarta_entrega
# cuarta_entrega_fin
# quinta_entrega
# quinta_entrega_fin
# costo
# forma_pago
# datos_pago
# documento_bases_url
# documento_tecnico_url
# contratacion_descripcion
# unidad_medida
# idioma
# considera_anticipo
# lugar_entrega
# fecha_estimada_inicio
# fecha_estimada_fin
# concurso_lugar
# concurso_direccion
# concurso_fecha
# propuestas_lugar
# propuestas_direccion
# propuestas_fecha
# fallo_lugar
# fallo_direccion
# fallo_fecha

# %%
# Extract the column names
col_names = []
for elt in cursor.description:
    col_names.append(elt[0])

# %%
# Create the dataframe, passing in the list of col_names extracted from the description
df_rds_aws = pd.DataFrame(results, columns=col_names)

# %%
df_rds_aws
# Out:
#                                              post_title      post_date  \
# 0     2ª ADQUISICIÓN DE EQUIPAMIENTO DE MOBILIARIO, ...  20/09/21 0:51
# 1                ADQUISICIÓN DE MOBILIARIO PARA OFICINA  20/09/21 0:44
# 2     EQUIPAMIENTO DE COCINAS PROTOTIPO PARA ALIMENT...  20/09/21 0:38
# 3            ADQUISICIÓN DE ENZIMAS Y PUNTAS CON FILTRO  20/09/21 0:27
# 4     TRABAJOS DE MANTENIMIENTO, CONSERVACIÓN Y REHA...  20/09/21 0:25
# ...                                                 ...            ...
# 3666  SUPERVISIÓN TÉCNICA Y ADMINISTRATIVA PARA LA R...  23/01/19 8:00
# 3667  SUPERVISIÓN TÉCNICA Y ADMINISTRATIVA PARA LA R...  23/01/19 8:00
# 3668  RECUPERACIÓN DE LA CAPACIDAD DE REGULACIÓN DE ...  23/01/19 8:00
# 3669  RECUPERACIÓN DE LA CAPACIDAD DE REGULACIÓN DE ...  23/01/19 8:00
# 3670  SERVICIO DE LIMPIEZA Y MANEJO DE DESECHOS EN O...  21/01/19 8:00
#
#               no_procedimiento  \
# 0           UNISA/LPI/003/2021
# 1          LPN/SACMEX/019/2021
# ...

# %%
cursor.close()
conn.close()

# %%
convocatorias  = pandas_data
convocatorias = convocatorias.drop(columns = '')

# %%
# convocatorias.columns

# %%
convocatorias.to_sql("inai.raw", con = conn, if_exists="replace",index=False)
conn = psycopg2.connect(conn_string)
conn.autocommit = True
cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# c:\users\rafae\onedrive\documentos\crehana\etl_and_elt_to_cmdx_water_consumption\crehana_md_bi_specialist\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# UndefinedTable: relation "sqlite_master" does not exist
# LINE 1: SELECT name FROM sqlite_master WHERE type='table' AND name=?...
#                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36420\1844459509.py in <module>
# ----> 1 convocatorias.to_sql("inai.raw", con = conn, if_exists="replace",index=False)
#       2 conn = psycopg2.connect(conn_string)
#       3 conn.autocommit = True
# ...

# %%
query = "SELECT * FROM inai.raw"

# %%
cursor = conn.cursor()
cursor.execute(query)
results = cursor.fetchall()

# %%
column_names = [desc[0] for desc in cursor.description]
for i in column_names:
    print(i)
# Out:
# id_registro
# folio
# fechasolicitud
# dependencia
# estatus
# medioentrada
# tiposolicitud
# descripcionsolicitud
# otrosdatos
# archivoadjuntosolicitud
# medioentrega
# fechalimite
# respuesta
# textorespuesta
# archivorespuesta
# fecharespuesta
# pais
# estado
# municipio
# codigopostal
# sector

# %%
# Extract the column names
col_names = []
for elt in cursor.description:
    col_names.append(elt[0])

# %%
# Create the dataframe, passing in the list of col_names extracted from the description
df_rds_aws = pd.DataFrame(results, columns=col_names)

# %%
df_rds_aws
# Out:
# Empty DataFrame
# Columns: [id_registro, folio, fechasolicitud, dependencia, estatus, medioentrada, tiposolicitud, descripcionsolicitud, otrosdatos, archivoadjuntosolicitud, medioentrega, fechalimite, respuesta, textorespuesta, archivorespuesta, fecharespuesta, pais, estado, municipio, codigopostal, sector]
# Index: []
#
# [0 rows x 21 columns]

# %%
cursor.close()
conn.close()
